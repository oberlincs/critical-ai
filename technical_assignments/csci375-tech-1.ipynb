# %% [markdown]
# # Technical Assignment 1
# *In which we make sure our assignment infrastructure works, and check in about some terms and concepts that we'll need to read technical literature.*

# %% [markdown]
# ## Goals
# * Get familiar with Google Colab.
# * Complete a brief machine-learning diagnostic exercise.
# * Make sure everyone can turn in an assignment.

# %% [markdown]
# ## Part 1: Behold, a Google Colab Notebook
# In this class, many of your assignments will be distributed as Google Colab notebooks like this one. Why to do this:
# * Colab is a convenient tool for writing and executing Python in your browser.
# * There's very little setup.
# * It lets me easily generate interactive documents that mix text cells, like this one, with code cells that you can execute (see below).
# * It gives us (some) free access to GPUs.
# * It's very nice.

# %% [markdown]
# ### Saving Changes and Getting Credit for your Work
#
# By following the Blackboard link to this assignment, you have opened a read-only copy of this notebook. In this state you should see the message `Changes will not be saved` to right of the notebook name at the top of the screen. In this mode you can still run code and edit things and do all sorts of brilliant work, but your instructor will not know about it.
#
# To be able to save your work, you first need to make your own copy of this notebook. This is easy: press the "Copy to drive" button, located near the top of this page.  The notebook's name (at the top) should change to "**Copy of ###.ipynb**" and, the warning message will disappear.

# %% [markdown]
# #### Task 1: Make your own copy of this notebook
# * Follow the instructions above to get your very own copy of this notebook.

# %% [markdown]
# #### Notebook name and location
#
# By default, the new copy which you have just created is saved into your [Google drive](https://drive.google.com/drive) under a folder called **Colab Notebooks**. You can view this folder by selecting **Locate in Drive** from the **file** menu.

# %% [markdown]
# #### Task 2: Rename your copy so the grader knows who you are
# * After you make your own copy, please rename the notebook to append your ObieID.
# * For example, if your ObieID is `emusk`, you would rename this notebook to `csci375-tech-1-emusk.ipynb`.

# %% [markdown]
# Now we are ready to start editing 👍. Note that you will need to follow these same initial steps for all of your assignments that use Colab Notebooks.

# %% [markdown]
# ### How to run code cells
#
# To run a specific code cell, you can either hover your mouse over it and click the circular play button on the left of the cell, or select the cell using the mouse or the up/down keys, and press **Shift+Enter**.
#
# After you run a cell, its output will appear beneath it.

# %% [markdown]
# #### Task 3: Run the code cell below.

# %%
print("Hi, I'm a code cell! Mouse over this text, then click the play button on the left to run me.")

# %% [markdown]
# #### Task 4: Watch a video, answer a question
#
# To get up to speed on Colab basics, please watch their 3-minute introduction, here:
# * [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI)
#
# Once you've watched the video, respond to the following question:

# %% [markdown]
# ##### Task 4 Question: spot the difference
#
# Did you notice that when the speaker was demonstrating the "Rich Interactive Coding experience," the example he gives is different from what the video actually shows? (If not, take a second look.)
#
# Once you've spotted the difference, click into the empty text cell below (where it says "Double-click (or enter) to edit") and give a one-sentence explanation of the discrepancy.

# %% [markdown]
# That's it for part 1! 🎉 You now know enough about Google Colab to do your homework. (Note that even though the video is short, it still mentions more features than we'll probably need for CSCI 375.)

# %% [markdown]
# [Credit: Some parts of this introduction were adapted from the [Colab quickstart page](https://colab.research.google.com/#scrollTo=5fCEDCU_qrC0). Explanations of cell and notebook operations were adapted from [Technion's introductory assignment](https://colab.research.google.com/github/technion046195/technion046195/blob/master/content/assignments/assignment_0_ex.ipynb).]

# %% [markdown]
# ## Part 2: Checking Comfort with some Terms, Notation and Concepts
# This section is a diagnostic, designed to help me understand what is new to people and what may already be obvious.
# ***Important: It is graded on completion, not correctness!***
#
# ### How to Complete This Section
# * Please read through each of the tasks below and answer to the best of your ability.
# * If you don't know how to answer or find the question confusing, that's very helpful to know. Please leave a note saying what you are confused about.
# * If you can answer the question, but need to look something up to do so, please also indicate that in your answer, along with whatever resource you used.

# %% [markdown]
# #### Task 5: Features and feature vectors
# Say you are building a dataset describing two species of imaginary creatures: trifluffs and kooblies, pictured below.

# %% [markdown]
# ![craiyon_creatures.png](data:image/png;base64,...)

# %% [markdown]
# [Credit: Craiyon Image Generator]

# %% [markdown]
# You hope to eventually use your dataset to create a program that can look at the features you have recorded about each creature and correctly determine whether it is a trifluff or a kooblie.
#
# In the next cell, please suggest some possible features you might record to make this possible.

# %% [markdown]
# Given the features you've proposed, now write an example of a feature vector for one of the creatures in the image:

# %% [markdown]
# #### Task 6: Sum Notation
# If you read about machine-learning papers, you are likely to come across a lot of sum notation. This task is meant to assess our collective familiarity with this notation:
# * $A$ is a list containing $n$ elements labeled $a_0, a_1, ... , a_{n-1}$.
# * $B$ is also a list of $n$ elements with analogous labels.
# * We want to calculate $z$, which is given by the equation $$\sum_{i=0}^{n-1}a_ib_i = z$$
#
# In the cell below, use a `for` loop to complete a function that calculates $z$ given $A$ and $B$.

# %%
def sum_elements(A, B):
  # add code here to complete the function
  return z

# %% [markdown]
# #### Task 7: Calculating the Dot Product
# * $\mathbf{x}$ and $\mathbf{w}$ are both n-dimensional vectors.
# * $z$ is a scalar value given by the equation $z = \mathbf{x}^T\mathbf{w}$.
#
# In the cell below, assume for simplicity that $\mathbf{x}$ and $\mathbf{w}$ are represented as Python lists, and use a `for` loop to complete a function that calculates $z$ given $\mathbf{x}$ and $\mathbf{w}.

# %%
def dot_product(x,w):
  # add code here to complete the function
  return z

# %% [markdown]
# ### Task 8: Interpreting the Dot Product
# The graph below shows two vectors, $\mathbf{a}$ and $\mathbf{b}$. The figure is drawn to scale.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To the best of your ability, estimate the dot product of the two vectors shown above.

# %% [markdown]
# This brings us to the end of part 2! All we have left is to make sure you can submit your notebook.

# %% [markdown]
# ## Part 3: Submitting your Notebook

# %% [markdown]
# ### Step 1: Check for completion
# **This assignment will be graded based on completion. To get credit, it must be complete!** This means you must:
# * Run all the code cells.
# * Complete all the tasks and exercises.
# * Answer all the questions.
#
# Take a moment now to look back over your notebook and check that it's ready to submit.

# %% [markdown]
# ### Step 2: Move your notebook to your assignment submission folder
# You submit your notebook by moving it to your assignment submission folder, a Google Drive folder that has been shared with you for this purpose.
# * The name of your assignment submission folder is `csci375-submit-here-<your_obieID>`, where `<your_obieID>` should be replaced with your personal ObieID.
# * For example, if your ObieID is `mzucker`, your assignment submission folder would be called `csci375-submit-here-mzucker`.
# * You should be able to find this folder by searching in Google Drive, or looking under the "Shared with me" section.
# * To avoid chaos, first please double check that you have renamed your notebook file to append your obieID to the filename.
# * When you are ready to submit, locate your copy of this file in your Google Drive, and move it into your assignment submission folder.
#
# Note that you will still be able to edit your file even after it is shared. However, after the submission deadline has passed a copy of your submission will be made for grading, and will not be able to receive any further edits.

# %% [markdown]
# That's it! Your first technical assignment is complete!

# %% [markdown]
# ![link_triforce.png](data:image/png;base64,...)
